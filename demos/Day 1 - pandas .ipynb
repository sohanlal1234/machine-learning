# %%
import pandas as pd

pd.__version__
# Out:
# '0.23.4'

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/abulbasar/data/master/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# # Operations for pandas dataframe
#
# 1. Basic information - rows, columns, column types
# 2. Basic statistics
# 3. Null values
# 4. Filter
# 5. ordering/sorting
# 6. grouping
# 7. pivot
# 8. merge

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
type(df.age)
# Out:
# pandas.core.series.Series

# %%
df.age
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
# 5       31
# 6       46
# 7       37
# 8       37
# 9       60
# 10      25
# 11      62
# 12      23
# 13      56
# 14      27
# 15      19
# 16      52
# 17      23
# 18      56
# 19      30
# 20      60
# 21      30
# 22      18
# 23      34
# 24      37
# 25      59
# 26      63
# 27      55
# 28      23
# 29      31
#         ..
# 1308    25
# 1309    41
# 1310    42
# 1311    33
# 1312    34
# 1313    19
# 1314    30
# 1315    18
# 1316    19
# 1317    18
# 1318    35
# 1319    39
# 1320    31
# 1321    62
# 1322    62
# 1323    42
# 1324    31
# 1325    61
# 1326    42
# 1327    51
# 1328    23
# 1329    52
# 1330    57
# 1331    23
# 1332    52
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df["age"]
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
# 5       31
# 6       46
# 7       37
# 8       37
# 9       60
# 10      25
# 11      62
# 12      23
# 13      56
# 14      27
# 15      19
# 16      52
# 17      23
# 18      56
# 19      30
# 20      60
# 21      30
# 22      18
# 23      34
# 24      37
# 25      59
# 26      63
# 27      55
# 28      23
# 29      31
#         ..
# 1308    25
# 1309    41
# 1310    42
# 1311    33
# 1312    34
# 1313    19
# 1314    30
# 1315    18
# 1316    19
# 1317    18
# 1318    35
# 1319    39
# 1320    31
# 1321    62
# 1322    62
# 1323    42
# 1324    31
# 1325    61
# 1326    42
# 1327    51
# 1328    23
# 1329    52
# 1330    57
# 1331    23
# 1332    52
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df[["age", "gender"]]
# Out:
#       age  gender
# 0      19  female
# 1      18    male
# 2      28    male
# 3      33    male
# 4      32    male
# 5      31  female
# 6      46  female
# 7      37  female
# 8      37    male
# 9      60  female
# 10     25    male
# 11     62  female
# 12     23    male
# 13     56  female
# 14     27    male
# 15     19    male
# 16     52  female
# 17     23    male
# 18     56    male
# 19     30    male
# 20     60  female
# 21     30  female
# 22     18    male
# 23     34  female
# 24     37    male
# 25     59  female
# 26     63  female
# 27     55  female
# 28     23    male
# 29     31    male
# ...   ...     ...
# 1308   25  female
# 1309   41    male
# 1310   42    male
# 1311   33  female
# 1312   34    male
# 1313   19  female
# 1314   30  female
# 1315   18    male
# 1316   19  female
# 1317   18    male
# 1318   35    male
# 1319   39  female
# 1320   31    male
# 1321   62    male
# 1322   62    male
# 1323   42  female
# 1324   31    male
# 1325   61    male
# ...

# %%
df.iloc[:,0:2]
# Out:
#       age  gender
# 0      19  female
# 1      18    male
# 2      28    male
# 3      33    male
# 4      32    male
# 5      31  female
# 6      46  female
# 7      37  female
# 8      37    male
# 9      60  female
# 10     25    male
# 11     62  female
# 12     23    male
# 13     56  female
# 14     27    male
# 15     19    male
# 16     52  female
# 17     23    male
# 18     56    male
# 19     30    male
# 20     60  female
# 21     30  female
# 22     18    male
# 23     34  female
# 24     37    male
# 25     59  female
# 26     63  female
# 27     55  female
# 28     23    male
# 29     31    male
# ...   ...     ...
# 1308   25  female
# 1309   41    male
# 1310   42    male
# 1311   33  female
# 1312   34    male
# 1313   19  female
# 1314   30  female
# 1315   18    male
# 1316   19  female
# 1317   18    male
# 1318   35    male
# 1319   39  female
# 1320   31    male
# 1321   62    male
# 1322   62    male
# 1323   42  female
# 1324   31    male
# 1325   61    male
# ...

# %%
a = [4, 6, 1, 10, 4, 5]
a[0]
# Out:
# 4

# %%
a = [4, 6, 1, 10, 4, 5]
a[0:2]
# Out:
# [4, 6]

# %%
a = [4, 6, 1, 10, 4, 5]
a[0:3]
# Out:
# [4, 6, 1]

# %%
a = [4, 6, 1, 10, 4, 5]
a[:3]
# Out:
# [4, 6, 1]

# %%
a = [4, 6, 1, 10, 4, 5]
a[-1]
# Out:
# 5

# %%
a = [4, 6, 1, 10, 4, 5]
a[-2:]
# Out:
# [4, 5]

# %%
a = [4, 6, 1, 10, 4, 5]
a[:]
# Out:
# [4, 6, 1, 10, 4, 5]

# %%
a = [4, 6, 1, 10, 4, 5]
a[::2]
# Out:
# [4, 1, 4]

# %%
a = [4, 6, 1, 10, 4, 5]
a[::-1]
# Out:
# [5, 4, 10, 1, 6, 4]

# %%
a = [4, 6, 1, 10, 4, 5]
a[-3]
# Out:
# 10

# %%
a = [4, 6, 1, 10, 4, 5]
a[-0]
# Out:
# 4

# %%
df.iloc[:10,0:2]
# Out:
#    age  gender
# 0   19  female
# 1   18    male
# 2   28    male
# 3   33    male
# 4   32    male
# 5   31  female
# 6   46  female
# 7   37  female
# 8   37    male
# 9   60  female

# %%
df.iloc[5:15,0:2]
# Out:
#     age  gender
# 5    31  female
# 6    46  female
# 7    37  female
# 8    37    male
# 9    60  female
# 10   25    male
# 11   62  female
# 12   23    male
# 13   56  female
# 14   27    male

# %%
df.iloc[5:15,:]
# Out:
#     age  gender    bmi  children smoker     region      charges
# 5    31  female  25.74         0     no  southeast   3756.62160
# 6    46  female  33.44         1     no  southeast   8240.58960
# 7    37  female  27.74         3     no  northwest   7281.50560
# 8    37    male  29.83         2     no  northeast   6406.41070
# 9    60  female  25.84         0     no  northwest  28923.13692
# 10   25    male  26.22         0     no  northeast   2721.32080
# 11   62  female  26.29         0    yes  southeast  27808.72510
# 12   23    male  34.40         0     no  southwest   1826.84300
# 13   56  female  39.82         0     no  southeast  11090.71780
# 14   27    male  42.13         0    yes  southeast  39611.75770

# %%
df.gender == "male"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10       True
# 11      False
# 12       True
# 13      False
# 14       True
# 15       True
# 16      False
# 17       True
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 1308    False
# 1309     True
# 1310     True
# 1311    False
# 1312     True
# 1313    False
# 1314    False
# 1315     True
# 1316    False
# 1317     True
# 1318     True
# 1319    False
# 1320     True
# 1321     True
# 1322     True
# 1323    False
# 1324     True
# 1325     True
# 1326    False
# 1327     True
# 1328    False
# 1329     True
# 1330    False
# 1331    False
# 1332    False
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# ...

# %%
df[df.gender == "male"]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 2      28   male  33.000         3     no  southeast   4449.46200
# 3      33   male  22.705         0     no  northwest  21984.47061
# 4      32   male  28.880         0     no  northwest   3866.85520
# 8      37   male  29.830         2     no  northeast   6406.41070
# 10     25   male  26.220         0     no  northeast   2721.32080
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 15     19   male  24.600         1     no  southwest   1837.23700
# 17     23   male  23.845         0     no  northeast   2395.17155
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# ...

# %%
df[(df.gender == "male") & (df.age <25)]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 12     23   male  34.400         0     no  southwest   1826.84300
# 15     19   male  24.600         1     no  southwest   1837.23700
# 17     23   male  23.845         0     no  northeast   2395.17155
# 22     18   male  34.100         0     no  southeast   1137.01100
# 28     23   male  17.385         1     no  northwest   2775.19215
# 30     22   male  35.600         0    yes  southwest  35585.57600
# 35     19   male  20.425         0     no  northwest   1625.43375
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 77     21   male  35.530         0     no  southeast   1532.46970
# 82     22   male  37.620         1    yes  southeast  37165.16380
# 105    20   male  28.025         1    yes  northwest  17560.37975
# 121    18   male  23.750         0     no  northeast   1705.62450
# ...

# %%
df.query("gender == 'male' and age <20")
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 15     19   male  24.600         1     no  southwest   1837.23700
# 22     18   male  34.100         0     no  southeast   1137.01100
# 35     19   male  20.425         0     no  northwest   1625.43375
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 121    18   male  23.750         0     no  northeast   1705.62450
# 133    19   male  25.555         0     no  northwest   1632.56445
# 136    19   male  34.100         0     no  southwest   1261.44200
# 149    19   male  28.400         1     no  southwest   1842.51900
# 157    18   male  25.175         0    yes  northeast  15518.18025
# 172    18   male  15.960         0     no  northeast   1694.79640
# 194    18   male  34.430         0     no  southeast   1137.46970
# 195    19   male  30.590         0     no  northwest   1639.56310
# ...

# %%
df.sort_values("bmi", ascending = False)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 847    23    male  50.380         1     no  southeast   2438.05520
# 116    58    male  49.060         0     no  southeast  11381.32540
# 286    46  female  48.070         2     no  northeast   9432.92530
# 1088   52    male  47.740         1     no  southeast   9748.91060
# 860    37  female  47.600         2    yes  southwest  46113.51100
# 401    47    male  47.520         1     no  southeast   8083.91980
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 438    52  female  46.750         5     no  southeast  12592.53450
# 547    54  female  46.700         2     no  southwest  11538.42100
# 454    32    male  46.530         2     no  southeast   4686.38870
# 930    26    male  46.530         1     no  southeast   2927.06470
# ...

# %%
df.sort_values(["age", "bmi"], ascending = False)
# Out:
#       age  gender     bmi  children smoker     region       charges
# 534    64    male  40.480         0     no  southeast  13831.115200
# 768    64  female  39.700         0     no  southwest  14319.031000
# 199    64  female  39.330         0     no  northeast  14901.516700
# 418    64    male  39.160         1     no  southeast  14418.280400
# 603    64  female  39.050         3     no  southeast  16085.127500
# 635    64    male  38.190         0     no  northeast  14410.932100
# 752    64    male  37.905         0     no  northwest  14210.535950
# 1241   64    male  36.960         2    yes  southeast  49577.662400
# 801    64  female  35.970         0     no  southeast  14313.846300
# 335    64    male  34.500         0     no  southwest  13822.803000
# 420    64    male  33.880         0    yes  southeast  46889.261200
# 328    64  female  33.800         1    yes  southwest  47928.030000
# 402    64  female  32.965         0     no  northwest  14692.669350
# ...

# %%
df.sort_values(["age", "bmi"], ascending = [True, False])
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 442    18    male  43.010         0     no  southeast   1149.39590
# 803    18  female  42.240         0    yes  southeast  38792.68560
# 781    18    male  41.140         0     no  southeast   1146.79660
# 728    18  female  40.280         0     no  northeast   2217.60120
# 898    18  female  40.260         0     no  southeast   1634.57340
# 942    18  female  40.185         0     no  northeast   2217.46915
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 600    18  female  39.160         0     no  southeast   1633.04440
# 1215   18    male  39.140         0     no  northeast  12890.05765
# 46     18  female  38.665         2     no  northeast   3393.35635
# 181    18  female  38.280         0     no  southeast   1631.82120
# 354    18  female  38.280         0     no  southeast  14133.03775
# ...

# %%
df.groupby("gender").age.mean()
# Out:
# gender
# female    39.503021
# male      38.917160
# Name: age, dtype: float64

# %%
df.gender.value_counts()
# Out:
# male      676
# female    662
# Name: gender, dtype: int64

# %%
df.groupby("gender").age.agg(["mean", "count"])
# Out:
#              mean  count
# gender
# female  39.503021    662
# male    38.917160    676

# %%
df.groupby("gender").agg({"age": "mean","bmi": "mean"})
# Out:
#               age        bmi
# gender
# female  39.503021  30.377749
# male    38.917160  30.943129

# %%
df.groupby("gender").agg({"age": ["mean", "median"]
                          ,"bmi": ["mean", "median"]})
# Out:
#               age               bmi
#              mean median       mean   median
# gender
# female  39.503021     40  30.377749  30.1075
# male    38.917160     39  30.943129  30.6875

# %%
df.pivot_table("age", "gender", "region")
# Out:
# region  northeast  northwest  southeast  southwest
# gender
# female  39.639752  39.591463  39.108571  39.703704
# male    38.901840  38.795031  38.783069  39.208589

# %%
df.pivot_table("age", "gender", "region", aggfunc="mean")
# Out:
# region  northeast  northwest  southeast  southwest
# gender
# female  39.639752  39.591463  39.108571  39.703704
# male    38.901840  38.795031  38.783069  39.208589

# %%
df.pivot_table("age", "gender", "region", aggfunc="median")
# Out:
# region  northeast  northwest  southeast  southwest
# gender
# female         40         40         39         40
# male           39         38         39         39
